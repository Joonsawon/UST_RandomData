# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
t = np.arange(0,10,0.1)
f = 0.1
def sin(k,t):
    return np.sin(2*np.pi*k*f*t)
    
a = sin(1,t)
b = sin(2,t)
c = sin(3,t)
x = a + b + c

plt.figure(figsize=(8,2))
plt.plot(t,x)
plt.grid(True)

plt.figure(figsize=(8,2))
#plt.subplot(311)
plt.plot(t,a)
plt.grid(True)
plt.figure(figsize=(8,2))
#plt.subplot(312)
plt.plot(t,b)
plt.grid(True)
plt.figure(figsize=(8,2))
#plt.subplot(313)
plt.plot(t,c)
plt.grid(True)

# %%
f = np.arange(0.04,0.2,0.04) # 주파수 생성
f = np.array(['f_0=0.04 Hz','f_1=0.08 Hz','f_2=0.12 Hz','f_3=0.16 Hz']) # 주파수 생성
M = np.array([0.39,0.2,0.008,0.1])

plt.bar(f,M)
# Out:
# <BarContainer object of 4 artists>

# %%
# 각각을 시간축 주파수로 그려보기

t = np.arange(0,25.6,0.1)
f = 0.04
def sin(k,t):
    return np.sin(2*np.pi*k*f*t)
    
a = M[0]*sin(1,t)
b = M[1]*sin(2,t)
c = M[2]*sin(3,t)
d = M[3]*sin(4,t)
x = a + b + c + d

plt.figure(figsize=(8,2))
plt.plot(t,x)
plt.grid(True)

plt.figure(figsize=(8,2))

plt.plot(t,a)
plt.plot(t,b)
plt.plot(t,c)
plt.plot(t,d)
plt.grid(True)

# %%
# 이산 데이터 연속 데이터

t = np.arange(0,10,0.1)
t_d = np.arange(0,10,0.5)

f = 0.1
def sin(k,t):
    return np.sin(2*np.pi*k*f*t)
    
b = sin(2,t)
b_d = sin(2,t_d)
plt.figure(figsize=(8,2))

#plt.plot(t,b)
plt.plot(t_d,b_d, 'o',markersize=5)
plt.grid(True)
